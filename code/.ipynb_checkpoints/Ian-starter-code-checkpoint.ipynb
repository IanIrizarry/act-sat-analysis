# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ## Executive Summary
#
# As part of the College Board Participation Improvement task force, our team was responsible for tracking statewide participation and providing a recommendation for where money might best be spent to improve SAT participation rates. Our goal is to work to increase the participation rate in the state of Illinois.
#
# In this report, we are going to do the following:
#
# 1. Take a look at aggregate SAT and ACT scores and participation rates from each state in the United States
# 2. Seek to identify trends in the data
# 3. Combine our data analysis with outside research to identify likely factors influencing participation rates and scores in various states.
#
# ### Background
#
# The SAT has been known as a long time leader in standardized testing. The rival standardized test, the ACT, has gained traction as a viable test to take for those interested in persuing a college education.
#
# ### Problem Statement
#
# Before looking at the data, our task force wanted to answer the question:
#
#     What influences participation rates, generally, and what influences a change in preference from one test to the other.
#
# ### Main Point
#
# #### Rates in Illinois flipped dramatically from ACT prioritization to SAT
#
# The first finding is that the participation rates in Illinois, for the SAT, were extremely low in 2017. However, despite the low participation rate in that year, in 2018, the rate increased drammatically to 99%. I found an explanation for this flip in my outside research. According to the Chicago Tribune, the ACT has dominated the market share of Illinois standardized testing for nearly two decades. However, in 2016, the state decided to run a bid to determine which standardize test would be provded in the state. That same year, the state awarded the bid to the Collage Board's SAT.
#
# #### Delay in participation improvement
#
# The second finding is that, although the College Board was awarded the bid, participation rates remained low until 2018. What that tells me is that preferences for the ACT remained strong until 2018. Additionally, state funding towards the SAT may have caused an obstacle. For 2 years in a row, the state struggled to form a state budget between 2015 and 2017.
#
# #### Participation rates are largely influenced by state involvement
#
# Finally, an analysis of the states with the highest and lowest participation rates revealed that many of the states either required SAT/ACT testing in highschool or provided funding for one test over the other. This state influence has a signficant impact on participation rates.
#
# ### Recommendations
#
# 1. We should identify the states that play a role in standardized testing. This includes:
#     - states that mandate testing
#     - states that pay for testing; and
#     - states that bid for testing
# 2. Based on the delay between the Illinois decision to support SAT testing and the increase in the SAT participation, we can speculate that testing preference may have an influence on decision making. Therefore, we should develop a brand message that demonstrates why states, schools, parents, and students should choose to take the SAT over the ACT.
# 3. Finally, the third recommendation would be to target the branding message at states that require ACT testing over another.
#
#
# ## Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code: Import the 2017 SAT and ACT data
act17 = pd.read_csv('/Users/ianirizarry/Desktop/DSIR/Submissions/project_1-master/data/act_2017.csv')
sat17 = pd.read_csv('/Users/ianirizarry/Desktop/DSIR/Submissions/project_1-master/data/sat_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code: Use .head to display the top 10 rows for the ACT 2017 data
act17.head(11)
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
#
#    Composite
# 0       21.0
# 1       19.2
# 2       19.8
# 3       19.7
# 4       19.4
# 5       22.8
# ...

# %%
#Code: Use .head to display the top 10 rows for the SAT 2017 data
sat17.head(11)
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5%                                 593
# 1                 Alaska           38%                                 547
# 2                Arizona           30%                                 563
# 3               Arkansas            3%                                 614
# 4             California           53%                                 531
# 5               Colorado           11%                                 606
# 6            Connecticut          100%                                 530
# 7               Delaware          100%                                 503
# 8   District of Columbia          100%                                 482
# 9                Florida           83%                                 520
# 10               Georgia           61%                                 535
#
#     Math  Total
# 0    572   1165
# 1    533   1080
# ...

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer:
#
# **ACT 2017**
#
# The ACT 2017 data is comprised of 52 rows and 7 columns. The first row in the data highlights: the State, Participation rate (in percentages), four subject areas (English, Math, Reading, and Science), and the composite score. The composite score is the average commulative score of the tested areas.
#
# The 51 remaining rows in the ACT 2017 data comprise of the 50 States, listed in alphabetical order and a row of National data.
#
# There are a few errors of note after exploring the data set:
# 1. There appears to be a data entry issue in one of the rows. In row 21 (Maryland) column 5 (Science), the entry inputted is 2.3. The score is unlikely 2.3 given the minimums in the other three categories and the scores from other States.
#
# 2. After gathering information on the data frame, I noted that 'Participation' and 'Composite' were being labeled as the data type 'object'. Since, visibly both of those features are floats, this will be something that has to be changed.
#
# 3. Finally, in row 52 (Wyoming), column 7 (Composite), there appears to be an entry with an 'x' at the end of the number. This is likely what is causing the 'Composite' feature to be labeled as a string.
#
# **SAT 2017**
#
# The SAT 2017 data is comprised of 51 rows and 5 columns. The first row in the data highlights: the State, the Participation rate (in percentages), two subject areas (Read and writing and Math), and the total score. The total score is the commulative score of the tested areas.
#
# The remaining 50 rows in the SAT 2017 data comprise of the 50 States, listed in alphabetical ordered.
#
# There are a few errors of note after exploring the data set:
# 1. Like the 2017 ACT data, the feature 'Participation' is being labeled as the data type 'object.' This will need to be changed to a float.
#
# 2. There also appears to be a data entry issue in one of the rows. In row 20 (Maryland), column 3 (Math), the entry inputted is 52. The score is unlikely 52 given the minimums in the other categories and the scores from other States.

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer:
#
# Based on my initial observation, both data sets appear to be complete.
#
# After running through the data, it appears that Maryland may have an issue with their Math values for the SAT.

# %%
act17.describe() # 'Participation' and 'Composite' are missing
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %%
act17.info() # 'Participation' and 'Composite' need to be a float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
act17.isnull().sum() #this identifies that whether the data is complete or not. If True (meaning there is incomplete data) then there is a null.
# Out:
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64

# %%
act17
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# ...

# %%
sat17.describe() # 'Participate' is missing
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
sat17.info() # 'Participate' needs to be a float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
sat17.isnull().sum() #this identifies that whether the data is complete or not. If True (meaning there is incomplete data) then there is a null.
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
sat17 # do a full view of the data
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5%                                 593
# 1                 Alaska           38%                                 547
# 2                Arizona           30%                                 563
# 3               Arkansas            3%                                 614
# 4             California           53%                                 531
# 5               Colorado           11%                                 606
# 6            Connecticut          100%                                 530
# 7               Delaware          100%                                 503
# 8   District of Columbia          100%                                 482
# 9                Florida           83%                                 520
# 10               Georgia           61%                                 535
# ...

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer:
#
# **ACT**
#
# According to the official ACT website, the minimum Composite score for the ACT is 1 and the maximum is 36.
#
# Using the description method on the ACT 2017 dataframe, the following maximums and minimums were identified:
#
# Min for English: 16.3
# Min for Math: 18
# Min for Reading: 18.1
# Min for Science: 2.3 (this minimum came from Maryland and is likely wrong)
#
# Max for English: 25.5
# Max for Math: 25.3
# Max for Reading: 26
# Max for Science: 24.9
#
# **SAT**
#
# According to the Princeton Review, the maximum SAT score is 1600, broken up into two parts worth 800 points a piece. The minimum score possible for the SAT is 400, broken up into two parts worth 200 points a piece.
#
# Using the description method on the SAT 2017 dataframe, the following maximums and minimums were identified:
#
# Min for Reading and Writing: 482
# Min for Math: 52 (this minimum came from Maryland and is likely wrong)
# Min for Total: 950
#
# Max for Reading and Writing: 644
# Max for Math: 651
# Max for Total: 1295

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %% [markdown]
# There are a few errors in the ACT 2017 data that need to be addressed:
#
# 1. There appears to be a data entry issue in one of the rows. In row 21 (Maryland) column 5 (Science), the entry inputted is 2.3. The score is unlikely 2.3 given the minimums in the other three categories and the scores from other States.
#
# 2. After gathering information on the data frame, I noted that 'Participation' and 'Composite' were being labeled as the data type 'object'. Since, visibly both of those features are floats, this will be something that has to be changed.
#
# 3. Finally, in row 52 (Wyoming), column 7 (Composite), there appears to be an entry with an 'x' at the end of the number. This is likely what is causing the 'Composite' feature to be labeled as a string.
#
# There are a few errors in the SAT 2017 data that need to be addressed:
#
# 1. Like the 2017 ACT data, the feature 'Participation' is being labeled as the data type 'object.' This will need to be changed to a float.
#
# 2. There also appears to be a data entry issue in one of the rows. In row 20 (Maryland), column 3 (Math), the entry inputted is 52. The score is unlikely 52 given the minimums in the other categories and the scores from other States.

# %%
act17 # we need to correct the Maryland entry 2.3
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# ...

# %%
act17.iloc[21,5] # use the .iloc method to identify the row and column of the data issue
# Out:
# 2.3

# %%
# add the = to change the data in that row, column
act17.iloc[21, 5] = 23.8

# %%
# confirm change
act17.iloc[21,5]
# Out:
# 23.8

# %%
sat17 #we need to correct the Maryland 52 Math score
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5%                                 593
# 1                 Alaska           38%                                 547
# 2                Arizona           30%                                 563
# 3               Arkansas            3%                                 614
# 4             California           53%                                 531
# 5               Colorado           11%                                 606
# 6            Connecticut          100%                                 530
# 7               Delaware          100%                                 503
# 8   District of Columbia          100%                                 482
# 9                Florida           83%                                 520
# 10               Georgia           61%                                 535
# ...

# %%
sat17.iloc[20,3] = 524 # the SAT 2017 data says that the score is 524 for Maryland

# %%
sat17.iloc[20,3] # confirm change
# Out:
# 524

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
# print the type of data that the file act17 is read as
print(type(act17))

# determine what type of data is within the dataframe act17
dtype_act17 = act17.dtypes
print(dtype_act17)

# 'Participation' and 'Composite' should be floats, not objects (strings)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %%
# print the type of data that the file sat17 is read as
print(type(sat17))

# determine what type of data is within the dataframe act17
dtype_sat17 = sat17.dtypes
print(dtype_sat17)

# 'Participation' should be a float, not an object (string)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# There are a few issues identified when inspecting the data:
#
# - 'Participation' and 'Composite in the 2017 ACT data are strings when they should be floats.
# - The data type in the 2017 SAT data is incorrect for the column 'Participation'.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.
#
# # This need to be a Function

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
# go to column participation. str.replace means replace as a string('%','')
#means replace the second with the first. astype(float) make the type a float.

act17['Participation'] = act17.Participation.str.replace('%', '').astype(float)

# %%
# go to column participation. str.replace means replace as a string('x','')
# means replace the second with the first. astype(float) make the type a float.

act17['Composite'] = act17.Composite.str.replace('x', '').astype(float)

# %%
# go to column participation. str.replace means replace as a string('%','')
# means replace the second with the first. astype(float) make the type a float.

sat17['Participation'] = sat17.Participation.str.replace('%', '').astype(float)

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
# display the top 5 rows to see that the participation changes have been made
sat17.head()
# Out:
#         State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5.0                                 593   572   1165
# 1      Alaska           38.0                                 547   533   1080
# 2     Arizona           30.0                                 563   553   1116
# 3    Arkansas            3.0                                 614   594   1208
# 4  California           53.0                                 531   524   1055

# %%
# display the top 5 rows to see that the participation changes have been made
act17.head()
# Out:
#       State  Participation  English  Math  Reading  Science  Composite
# 0  National           60.0     20.3  20.7     21.4     21.0       21.0
# 1   Alabama          100.0     18.9  18.4     19.7     19.4       19.2
# 2    Alaska           65.0     18.7  19.8     20.4     19.9       19.8
# 3   Arizona           62.0     18.6  19.8     20.1     19.8       19.7
# 4  Arkansas          100.0     18.9  19.0     19.7     19.5       19.4

# %%
# verify that the 'x' has been removed from the column values
print(act17['Composite'])
# Out:
# 0     21.0
# 1     19.2
# 2     19.8
# 3     19.7
# 4     19.4
# 5     22.8
# 6     20.8
# 7     25.2
# 8     24.1
# 9     24.2
# 10    19.8
# 11    21.4
# 12    19.0
# 13    22.3
# 14    21.4
# 15    22.6
# 16    21.9
# 17    21.7
# 18    20.0
# 19    19.5
# 20    24.3
# 21    23.6
# 22    25.4
# 23    24.1
# 24    21.5
# 25    18.6
# 26    20.4
# 27    20.3
# 28    21.4
# 29    17.8
# 30    25.5
# 31    23.9
# 32    19.7
# 33    24.2
# 34    19.1
# 35    20.3
# 36    22.0
# 37    19.4
# 38    21.8
# 39    23.7
# 40    24.0
# 41    18.7
# 42    21.8
# 43    19.8
# 44    20.7
# 45    20.3
# 46    23.6
# 47    23.8
# 48    21.9
# 49    20.4
# 50    20.5
# 51    20.2
# Name: Composite, dtype: float64

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
# print what type of data type act17 is
print(type(act17))

# print 
dtype_act17 = act17.dtypes
print(dtype_act17)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %%
print(type(sat17))
dtype_sat17 = sat17.dtypes
print(dtype_sat17)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# # Use Map to change all column names at once
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
#display the top 5 rows
act17.head()
# Out:
#       State  Participation  English  Math  Reading  Science  Composite
# 0  National           60.0     20.3  20.7     21.4     21.0       21.0
# 1   Alabama          100.0     18.9  18.4     19.7     19.4       19.2
# 2    Alaska           65.0     18.7  19.8     20.4     19.9       19.8
# 3   Arizona           62.0     18.6  19.8     20.1     19.8       19.7
# 4  Arkansas          100.0     18.9  19.0     19.7     19.5       19.4

# %%
# reference the dataframe act17 and rename the columns (old value, new value)
# use inplace=True to make the changes permanent
act17.rename(columns={
    'State' : 'state',
    'Participation' : 'a_participation_17',
    'English':'a_english_17',
    'Math' : 'a_math_17',
    'Reading' : 'a_reading_17',
    'Science' : 'a_science_17',
    'Composite' : 'a_composite_17',
}, inplace=True)

# %%
#display the top 5 rows
act17.head()
# Out:
#       state  a_participation_17  a_english_17  a_math_17  a_reading_17  \
# 0  National                60.0          20.3       20.7          21.4
# 1   Alabama               100.0          18.9       18.4          19.7
# 2    Alaska                65.0          18.7       19.8          20.4
# 3   Arizona                62.0          18.6       19.8          20.1
# 4  Arkansas               100.0          18.9       19.0          19.7
#
#    a_science_17  a_composite_17
# 0          21.0            21.0
# 1          19.4            19.2
# 2          19.9            19.8
# 3          19.8            19.7
# 4          19.5            19.4

# %%
# display the top 5 rows
sat17.head()
# Out:
#         State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5.0                                 593   572   1165
# 1      Alaska           38.0                                 547   533   1080
# 2     Arizona           30.0                                 563   553   1116
# 3    Arkansas            3.0                                 614   594   1208
# 4  California           53.0                                 531   524   1055

# %%
# reference the dataframe sat17 and rename the columns (old value, new value)
# use inplace=True to make the changes permanent
sat17.rename(columns={
    'State' : 'state',
    'Participation' : 's_participation_17',
    'Evidence-Based Reading and Writing':'s_rw_17',
    'Math' : 's_math_17',
    'Total' : 's_total_17',
}, inplace=True)

# %%
# display the top 5 rows
sat17.head()
# Out:
#         state  s_participation_17  s_rw_17  s_math_17  s_total_17
# 0     Alabama                 5.0      593        572        1165
# 1      Alaska                38.0      547        533        1080
# 2     Arizona                30.0      563        553        1116
# 3    Arkansas                 3.0      614        594        1208
# 4  California                53.0      531        524        1055

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# state	participation	english	math	reading	science	composite

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|Object|ACT or SAT|The state in which the testing took place||
# a_participation_17|Float|ACT|The percentage of students who recorded that specific state as their testing state for the 2017 ACT|
# a_english_17|Float|ACT|The ACT english Score (1-36)|
# a_math_17|Float|ACT|The ACT math Score (1-36)|
# a_reading_17|Float|ACT|The ACT reading Score (1-36)|
# a_science_17|Float|ACT|The ACT science Score (1-36)|
# a_composite_17|Float|ACT|The ACT composite Score (1-36)|
# s_participation_17|Float|SAT| The percentage of students who recorded that specific state as their testing state for the 2017 SAT|
# s_rw_17|Int|SAT|The SAT writing Score (200-800)|
# s_math_17|Int|SAT|The SAT math Score (200-800)|
# s_total_17|Int|SAT|The SAT total Score (200-800)|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
# run the entire dataframe to assess whether any rows appear to be unnecessary
act17
# the 'National' row appears to be an unnecessary row
# Out:
#                    state  a_participation_17  a_english_17  a_math_17  \
# 0               National                60.0          20.3       20.7
# 1                Alabama               100.0          18.9       18.4
# 2                 Alaska                65.0          18.7       19.8
# 3                Arizona                62.0          18.6       19.8
# 4               Arkansas               100.0          18.9       19.0
# 5             California                31.0          22.5       22.7
# 6               Colorado               100.0          20.1       20.3
# 7            Connecticut                31.0          25.5       24.6
# 8               Delaware                18.0          24.1       23.4
# 9   District of Columbia                32.0          24.4       23.5
# 10               Florida                73.0          19.0       19.4
# 11               Georgia                55.0          21.0       20.9
# ...

# %%
# run the entire dataframe to assess whether any rows appear to be unnecessary
sat17
# no row appears to be unnecessary
# Out:
#                    state  s_participation_17  s_rw_17  s_math_17  s_total_17
# 0                Alabama                 5.0      593        572        1165
# 1                 Alaska                38.0      547        533        1080
# 2                Arizona                30.0      563        553        1116
# 3               Arkansas                 3.0      614        594        1208
# 4             California                53.0      531        524        1055
# 5               Colorado                11.0      606        595        1201
# 6            Connecticut               100.0      530        512        1041
# 7               Delaware               100.0      503        492         996
# 8   District of Columbia               100.0      482        468         950
# 9                Florida                83.0      520        497        1017
# 10               Georgia                61.0      535        515        1050
# ...

# %%
# by selecting the range, we can indicate which row we want to drop
act17 = act17[1:]

# %%
# verify that the row 'National' is gone
act17
# Out:
#                    state  a_participation_17  a_english_17  a_math_17  \
# 1                Alabama               100.0          18.9       18.4
# 2                 Alaska                65.0          18.7       19.8
# 3                Arizona                62.0          18.6       19.8
# 4               Arkansas               100.0          18.9       19.0
# 5             California                31.0          22.5       22.7
# 6               Colorado               100.0          20.1       20.3
# 7            Connecticut                31.0          25.5       24.6
# 8               Delaware                18.0          24.1       23.4
# 9   District of Columbia                32.0          24.4       23.5
# 10               Florida                73.0          19.0       19.4
# 11               Georgia                55.0          21.0       20.9
# 12                Hawaii                90.0          17.8       19.2
# ...

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
# use pd.merge to merge the 2017 ACT and SAT dataframes
# since both datasets are dataframes, we only need to input the two dataframes,
tests2017 = pd.merge(act17, sat17)

# %%
# confirm that the merge was successful
tests2017.head(11)
# Out:
#                    state  a_participation_17  a_english_17  a_math_17  \
# 0                Alabama               100.0          18.9       18.4
# 1                 Alaska                65.0          18.7       19.8
# 2                Arizona                62.0          18.6       19.8
# 3               Arkansas               100.0          18.9       19.0
# 4             California                31.0          22.5       22.7
# 5               Colorado               100.0          20.1       20.3
# 6            Connecticut                31.0          25.5       24.6
# 7               Delaware                18.0          24.1       23.4
# 8   District of Columbia                32.0          24.4       23.5
# 9                Florida                73.0          19.0       19.4
# 10               Georgia                55.0          21.0       20.9
#
#     a_reading_17  a_science_17  a_composite_17  s_participation_17  s_rw_17  \
# ...

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#code
tests2017.to_csv('../data/combined_2017.csv', index = False)

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Read in the `sat_2018.csv` and `act_2018.csv` files and assign them to appropriately named pandas dataframes. For the **2018 ACT Data**, only the `Composite` scores are available. Repeat the same processes to clean the 2018 data here as you were instructed in the previous sections above.

# %%
# import the 2018 SAT data and ACT data
act18 = pd.read_csv('/Users/ianirizarry/Desktop/DSIR/Submissions/project_1-master/data/act_2018.csv')
sat18 = pd.read_csv('/Users/ianirizarry/Desktop/DSIR/Submissions/project_1-master/data/sat_2018.csv')

# %%
act18.info()
# it appears that 'Participation' should be a float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
act18.describe() # everything within the composite score looks good
# Out:
#        Composite
# count  52.000000
# mean   21.544231
# std     2.119417
# min    17.700000
# 25%    19.975000
# 50%    21.300000
# 75%    23.725000
# max    25.600000

# %%
# look through the dataframe to see if anything stands out
act18
# there are duplicate 'Maine' entries
# Out:
#                    State Participation  Composite
# 0                Alabama          100%       19.1
# 1                 Alaska           33%       20.8
# 2                Arizona           66%       19.2
# 3               Arkansas          100%       19.4
# 4             California           27%       22.7
# 5               Colorado           30%       23.9
# 6            Connecticut           26%       25.6
# 7               Delaware           17%       23.8
# 8   District of columbia           32%       23.6
# 9                Florida           66%       19.9
# 10               Georgia           53%       21.4
# 11                Hawaii           89%       18.9
# 12                 Idaho           36%       22.3
# 13              Illinois           43%       23.9
# 14               Indiana           32%       22.5
# 15                  Iowa           68%       21.8
# 16                Kansas           71%       21.6
# 17              Kentucky          100%       20.2
# ...

# %%
#capitalize District of Columbia
# remove all duplicates in the dataframe and keep the last value
act18 = act18.drop_duplicates(keep='last')

# %%
# confirm duplicates have been removed.
act18
# Out:
#                    State Participation  Composite
# 0                Alabama          100%       19.1
# 1                 Alaska           33%       20.8
# 2                Arizona           66%       19.2
# 3               Arkansas          100%       19.4
# 4             California           27%       22.7
# 5               Colorado           30%       23.9
# 6            Connecticut           26%       25.6
# 7               Delaware           17%       23.8
# 8   District of columbia           32%       23.6
# 9                Florida           66%       19.9
# 10               Georgia           53%       21.4
# 11                Hawaii           89%       18.9
# 12                 Idaho           36%       22.3
# 13              Illinois           43%       23.9
# 14               Indiana           32%       22.5
# 15                  Iowa           68%       21.8
# 16                Kansas           71%       21.6
# 17              Kentucky          100%       20.2
# ...

# %%
# change the 2018 ACT data's 'Participation' from a string to a float. The % currently is what makes it a string
act18['Participation'] = act18.Participation.str.replace('%', '').astype(float)
# Out:
# /Users/ianirizarry/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# For consistency with the 2017 data, change name to 'District of Columbia' # use .loc = [row, column]
act18.loc[act18['State'] == 'District of columbia', 'State'] = 'District of Columbia'
# Out:
# /Users/ianirizarry/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
# referenace the dataframe act18 and use the .rename() method to rename the columns (old value: new value)
# use inplace=True to make the changes permanent
act18.rename(columns={
   'State' : 'state',
   'Participation' : 'a_participation_18',
   'Composite' : 'a_composite_18',
}, inplace=True)
# Out:
# /Users/ianirizarry/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
# confirm that the % in 'Participation' has been removed and that 'District of columbia' is now 'District of Columbia'
# confirm that the headers are lowercase and renamed
act18
# Out:
#                    state  a_participation_18  a_composite_18
# 0                Alabama               100.0            19.1
# 1                 Alaska                33.0            20.8
# 2                Arizona                66.0            19.2
# 3               Arkansas               100.0            19.4
# 4             California                27.0            22.7
# 5               Colorado                30.0            23.9
# 6            Connecticut                26.0            25.6
# 7               Delaware                17.0            23.8
# 8   District of Columbia                32.0            23.6
# 9                Florida                66.0            19.9
# 10               Georgia                53.0            21.4
# 11                Hawaii                89.0            18.9
# 12                 Idaho                36.0            22.3
# 13              Illinois                43.0            23.9
# ...

# %%
# identify basic information on the dataset
sat18.info()

# 'Participation' is an 'object' but should be a float.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
# reference the column 'Participation' in the dataframe sat18
# reference the dataframe.column, indicate to replace a string ('reference what you want to change, reference what you want to change it to')
# use .astype to change it to a (float)
sat18['Participation'] = sat18.Participation.str.replace('%', '').astype(float)

# %%
# rename columns and make them lowercase
sat18.rename(columns={
   'State' : 'state',
   'Participation' : 's_participation_18',
    'Evidence-Based Reading and Writing':'s_rw_18',
    'Math' : 's_math_18',
    'Total' : 's_total_18',
}, inplace=True)

# %%
# confirm participation is fixed and that the columns are lowercase
sat18.head()
# Out:
#         state  s_participation_18  s_rw_18  s_math_18  s_total_18
# 0     Alabama                 6.0      595        571        1166
# 1      Alaska                43.0      562        544        1106
# 2     Arizona                29.0      577        572        1149
# 3    Arkansas                 5.0      592        576        1169
# 4  California                60.0      540        536        1076

# %%
sat18 # everything looks good in here
# Out:
#                    state  s_participation_18  s_rw_18  s_math_18  s_total_18
# 0                Alabama                 6.0      595        571        1166
# 1                 Alaska                43.0      562        544        1106
# 2                Arizona                29.0      577        572        1149
# 3               Arkansas                 5.0      592        576        1169
# 4             California                60.0      540        536        1076
# 5               Colorado               100.0      519        506        1025
# 6            Connecticut               100.0      535        519        1053
# 7               Delaware               100.0      505        492         998
# 8   District of Columbia                92.0      497        480         977
# 9                Florida                56.0      550        549        1099
# 10               Georgia                70.0      542        522        1064
# ...

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
# create a new variable of the merged 2018 SAT and ACT data
tests2018 = pd.merge(sat18, act18)

# %%
# create a new variable of the combined datasets for 2017 and 2018
final = pd.merge(tests2017, tests2018)

# %%
# verify that merge completed successfully
final.head()
# Out:
#         state  a_participation_17  a_english_17  a_math_17  a_reading_17  \
# 0     Alabama               100.0          18.9       18.4          19.7
# 1      Alaska                65.0          18.7       19.8          20.4
# 2     Arizona                62.0          18.6       19.8          20.1
# 3    Arkansas               100.0          18.9       19.0          19.7
# 4  California                31.0          22.5       22.7          23.1
#
#    a_science_17  a_composite_17  s_participation_17  s_rw_17  s_math_17  \
# 0          19.4            19.2                 5.0      593        572
# 1          19.9            19.8                38.0      547        533
# 2          19.8            19.7                30.0      563        553
# 3          19.5            19.4                 3.0      614        594
# 4          22.2            22.8                53.0      531        524
#
#    s_total_17  s_participation_18  s_rw_18  s_math_18  s_total_18  \
# ...

# %%
# save final as final.csv
final.to_csv('../data/final.csv', index = False)

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
# use .T after the method to transpose the results
final.describe().T
# Out:
#                     count         mean        std    min      25%     50%  \
# a_participation_17   51.0    65.254902  32.140842    8.0    31.00    69.0
# a_english_17         51.0    20.931373   2.353677   16.3    19.00    20.7
# a_math_17            51.0    21.182353   1.981989   18.0    19.40    20.9
# a_reading_17         51.0    22.013725   2.067271   18.1    20.45    21.8
# a_science_17         51.0    21.462745   1.753392   18.2    19.95    21.3
# a_composite_17       51.0    21.519608   2.020695   17.8    19.80    21.4
# s_participation_17   51.0    39.803922  35.276632    2.0     4.00    38.0
# s_rw_17              51.0   569.117647  45.666901  482.0   533.50   559.0
# s_math_17            51.0   556.882353  47.121395  468.0   523.50   548.0
# s_total_17           51.0  1126.098039  92.494812  950.0  1055.50  1107.0
# s_participation_18   51.0    45.745098  37.314256    2.0     4.50    52.0
# s_rw_18              51.0   563.686275  47.502627  480.0   534.50   552.0
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
data = []
def stddev( data ):
    num = 0
    for x in data: num += ((x - sum(data)/len(data))**2)
    # every iteration subtracks the mean value of a list [sum(data)/len(data)]
    #from every [x] element of a list and then raises to the second power [**2]
    print((num/(len(data)-1))**0.5) # then divide by n-1 [len(data)-1] and extract the root of 2 [**0.5]

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
#Code:
# make sd a dictionary
# let the iterative 'key' in the dictionary have the value be the stddev()
# use a for loop to cycle through all the keys and values in the index final
# use the .drop method t
sd = {key:stddev(values) for key, values in final.drop(labels = 'state', axis = 1).items()}
# Out:
# 32.14084201588683
# 2.35367713980303
# 1.9819894936505533
# 2.0672706264873146
# 1.7533922304280611
# 2.020694891154341
# 35.276632270013046
# 45.66690138768932
# 47.12139516560329
# 92.49481172519046
# 37.31425633039196
# 47.50262737831599
# 47.77262322095955
# 94.15508275097599
# 34.03708473496081
# 2.111583366510896

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# The manually calculated standard deviations match the output from the pandas .describe() method perfectly. However, there is a slight degree of variance between the pandas and manual standard deviation and the numpy std.() method.

# %%
# transpose the describe() results by adding .T
final.describe().T
# Out:
#                     count         mean        std    min      25%     50%  \
# a_participation_17   51.0    65.254902  32.140842    8.0    31.00    69.0
# a_english_17         51.0    20.931373   2.353677   16.3    19.00    20.7
# a_math_17            51.0    21.182353   1.981989   18.0    19.40    20.9
# a_reading_17         51.0    22.013725   2.067271   18.1    20.45    21.8
# a_science_17         51.0    21.462745   1.753392   18.2    19.95    21.3
# a_composite_17       51.0    21.519608   2.020695   17.8    19.80    21.4
# s_participation_17   51.0    39.803922  35.276632    2.0     4.00    38.0
# s_rw_17              51.0   569.117647  45.666901  482.0   533.50   559.0
# s_math_17            51.0   556.882353  47.121395  468.0   523.50   548.0
# s_total_17           51.0  1126.098039  92.494812  950.0  1055.50  1107.0
# s_participation_18   51.0    45.745098  37.314256    2.0     4.50    52.0
# s_rw_18              51.0   563.686275  47.502627  480.0   534.50   552.0
# ...

# %%
# use the numpy std method to compare the std results with the above describe() method and the stddev function created.
np.std(final)
# Out:
# a_participation_17    31.824176
# a_english_17           2.330488
# a_math_17              1.962462
# a_reading_17           2.046903
# a_science_17           1.736117
# a_composite_17         2.000786
# s_participation_17    34.929071
# s_rw_17               45.216970
# s_math_17             46.657134
# s_total_17            91.583511
# s_participation_18    36.946619
# s_rw_18               47.034610
# s_math_18             47.301946
# s_total_18            93.227424
# a_participation_18    33.701736
# a_composite_18         2.090779
# dtype: float64

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# **Lowest participation rate**

# %%
#Lowest participation rates for 2017 SAT

sat17__low_part_rates = final.sort_values('s_participation_17', ascending=True).head(5)
sat17__low_part_rates
# Out:
#            state  a_participation_17  a_english_17  a_math_17  a_reading_17  \
# 34  North Dakota                98.0          19.0       20.4          20.5
# 24   Mississippi               100.0          18.2       18.1          18.8
# 15          Iowa                67.0          21.2       21.3          22.6
# 25      Missouri               100.0          19.8       19.9          20.8
# 44          Utah               100.0          19.5       19.9          20.8
#
#     a_science_17  a_composite_17  s_participation_17  s_rw_17  s_math_17  \
# 34          20.6            20.3                 2.0      635        621
# 24          18.8            18.6                 2.0      634        607
# 15          22.1            21.9                 2.0      641        635
# 25          20.5            20.4                 3.0      640        631
# 44          20.6            20.3                 3.0      624        614
#
#     s_total_17  s_participation_18  s_rw_18  s_math_18  s_total_18  \
# ...

# %% [markdown]
# The lowest participation rates for the 2017 SAT are the following states (from lowest to highest):
#
# 1. North Dakota
# 2. Mississippi
# 3. Iowa
# 4. Missouri
# 5. Utah

# %%
#Lowest participation rates for 2018 SAT

sat18__low_part_rates = final.sort_values('s_participation_18', ascending=True).head(5)
sat18__low_part_rates
# Out:
#            state  a_participation_17  a_english_17  a_math_17  a_reading_17  \
# 34  North Dakota                98.0          19.0       20.4          20.5
# 50       Wyoming               100.0          19.4       19.8          20.8
# 41  South Dakota                80.0          20.7       21.5          22.3
# 27      Nebraska                84.0          20.9       20.9          21.9
# 49     Wisconsin               100.0          19.7       20.4          20.6
#
#     a_science_17  a_composite_17  s_participation_17  s_rw_17  s_math_17  \
# 34          20.6            20.3                 2.0      635        621
# 50          20.6            20.2                 3.0      626        604
# 41          22.0            21.8                 3.0      612        603
# 27          21.5            21.4                 3.0      629        625
# 49          20.9            20.5                 3.0      642        649
#
#     s_total_17  s_participation_18  s_rw_18  s_math_18  s_total_18  \
# ...

# %% [markdown]
# The lowest participation rates for the 2018 SAT are the following states (from lowest to highest):
#
# 1. North Dakota
# 2. Wyoming
# 3. South Dakota
# 4. Nebraska
# 5. Wisconsin

# %%
#Lowest participation rates for 2017 ACT

act17__low_part_rates = final.sort_values('a_participation_17', ascending=True).head(5)
act17__low_part_rates
# Out:
#             state  a_participation_17  a_english_17  a_math_17  a_reading_17  \
# 19          Maine                 8.0          24.2       24.0          24.8
# 29  New Hampshire                18.0          25.4       25.1          26.0
# 7        Delaware                18.0          24.1       23.4          24.8
# 39   Rhode Island                21.0          24.0       23.3          24.7
# 38   Pennsylvania                23.0          23.4       23.4          24.2
#
#     a_science_17  a_composite_17  s_participation_17  s_rw_17  s_math_17  \
# 19          23.7            24.3                95.0      513        499
# 29          24.9            25.5                96.0      532        520
# 7           23.6            24.1               100.0      503        492
# 39          23.4            24.0                71.0      539        524
# 38          23.3            23.7                65.0      540        531
#
# ...

# %% [markdown]
# The lowest participation rates for the 2017 ACT are the following states (from lowest to highest):
#
# 1. Maine
# 2. New Hampshire
# 3. Deleware
# 4. Rhode Island
# 5. Pennsylvania

# %%
#Lowest participation rates for 2018 ACT

act18__low_part_rates = final.sort_values('a_participation_18', ascending=True).head(5)
act18__low_part_rates
# Out:
#             state  a_participation_17  a_english_17  a_math_17  a_reading_17  \
# 19          Maine                 8.0          24.2       24.0          24.8
# 39   Rhode Island                21.0          24.0       23.3          24.7
# 29  New Hampshire                18.0          25.4       25.1          26.0
# 7        Delaware                18.0          24.1       23.4          24.8
# 38   Pennsylvania                23.0          23.4       23.4          24.2
#
#     a_science_17  a_composite_17  s_participation_17  s_rw_17  s_math_17  \
# 19          23.7            24.3                95.0      513        499
# 39          23.4            24.0                71.0      539        524
# 29          24.9            25.5                96.0      532        520
# 7           23.6            24.1               100.0      503        492
# 38          23.3            23.7                65.0      540        531
#
# ...

# %% [markdown]
# The lowest participation rates for the 2018 ACT are the following states (from lowest to highest):
#
# 1. Maine
# 2. Rhode Island
# 3. New Hampshire
# 4. Delaware
# 5. Pennsylvania

# %% [markdown]
# **Highest participation rate**

# %%
#Highest participation rates for 2017 SAT
sat17__low_part_rates = final.sort_values('s_participation_17', ascending=False).head(5)
sat17__low_part_rates
# Out:
#                    state  a_participation_17  a_english_17  a_math_17  \
# 8   District of Columbia                32.0          24.4       23.5
# 22              Michigan                29.0          24.1       23.7
# 6            Connecticut                31.0          25.5       24.6
# 7               Delaware                18.0          24.1       23.4
# 29         New Hampshire                18.0          25.4       25.1
#
#     a_reading_17  a_science_17  a_composite_17  s_participation_17  s_rw_17  \
# 8           24.9          23.5            24.2               100.0      482
# 22          24.5          23.8            24.1               100.0      509
# 6           25.6          24.6            25.2               100.0      530
# 7           24.8          23.6            24.1               100.0      503
# 29          26.0          24.9            25.5                96.0      532
#
#     s_math_17  s_total_17  s_participation_18  s_rw_18  s_math_18  s_total_18  \
# ...

# %% [markdown]
# The highest participation rates for the 2017 SAT are the following states (from highest to lowest):
#
# 1. District of Columbia
# 2. Michigan
# 3. Connecticut
# 4. Delaware
# 5. New Hampshire

# %%
#Highest participation rates for 2018 SAT

sat18__low_part_rates = final.sort_values('s_participation_18', ascending=False).head(5)
sat18__low_part_rates
# Out:
#           state  a_participation_17  a_english_17  a_math_17  a_reading_17  \
# 5      Colorado               100.0          20.1       20.3          21.2
# 6   Connecticut                31.0          25.5       24.6          25.6
# 7      Delaware                18.0          24.1       23.4          24.8
# 22     Michigan                29.0          24.1       23.7          24.5
# 12        Idaho                38.0          21.9       21.8          23.0
#
#     a_science_17  a_composite_17  s_participation_17  s_rw_17  s_math_17  \
# 5           20.9            20.8                11.0      606        595
# 6           24.6            25.2               100.0      530        512
# 7           23.6            24.1               100.0      503        492
# 22          23.8            24.1               100.0      509        495
# 12          22.1            22.3                93.0      513        493
#
#     s_total_17  s_participation_18  s_rw_18  s_math_18  s_total_18  \
# ...

# %% [markdown]
# The highest participation rates for the 2018 SAT are the following states (from highest to lowest):
#
# 1. Colorado
# 2. Connecticut
# 3. Deleware
# 4. Michigan
# 5. Idaho

# %%
#Highest participation rates for 2017 ACT

act17__low_part_rates = final.sort_values('a_participation_17', ascending=False).head(5)
sat17__low_part_rates
# Out:
#                    state  a_participation_17  a_english_17  a_math_17  \
# 8   District of Columbia                32.0          24.4       23.5
# 22              Michigan                29.0          24.1       23.7
# 6            Connecticut                31.0          25.5       24.6
# 7               Delaware                18.0          24.1       23.4
# 29         New Hampshire                18.0          25.4       25.1
#
#     a_reading_17  a_science_17  a_composite_17  s_participation_17  s_rw_17  \
# 8           24.9          23.5            24.2               100.0      482
# 22          24.5          23.8            24.1               100.0      509
# 6           25.6          24.6            25.2               100.0      530
# 7           24.8          23.6            24.1               100.0      503
# 29          26.0          24.9            25.5                96.0      532
#
#     s_math_17  s_total_17  s_participation_18  s_rw_18  s_math_18  s_total_18  \
# ...

# %% [markdown]
# The highest participation rates for the 2017 ACT are the following states (from highest to lowest):
#
# 1. District of Columbia
# 2. Michigan
# 3. Connecticut
# 4. Deleware
# 5. New Hampshire

# %%
#Highest participation rates for 2018 ACT

act18__low_part_rates = final.sort_values('a_participation_18', ascending=False).head(5)
act18__low_part_rates
# Out:
#         state  a_participation_17  a_english_17  a_math_17  a_reading_17  \
# 0     Alabama               100.0          18.9       18.4          19.7
# 17   Kentucky               100.0          19.6       19.4          20.5
# 49  Wisconsin               100.0          19.7       20.4          20.6
# 44       Utah               100.0          19.5       19.9          20.8
# 42  Tennessee               100.0          19.5       19.2          20.1
#
#     a_science_17  a_composite_17  s_participation_17  s_rw_17  s_math_17  \
# 0           19.4            19.2                 5.0      593        572
# 17          20.1            20.0                 4.0      631        616
# 49          20.9            20.5                 3.0      642        649
# 44          20.6            20.3                 3.0      624        614
# 42          19.9            19.8                 5.0      623        604
#
#     s_total_17  s_participation_18  s_rw_18  s_math_18  s_total_18  \
# ...

# %% [markdown]
# The highest participation rates for the 2018 ACT are the following states (from highest to lowest):
#
# 1. Alabama
# 2. Kentucky
# 3. Wisconsin
# 4. Utah
# 5. Tennessee

# %% [markdown]
# **Lowest total/composite scores**
# Which states have the highest and lowest mean total/composite scores for the:
# 2017 SAT?
# 2018 SAT?
# 2017 ACT?
# 2018 ACT?

# %%
#Lowest total scores for 2017 SAT

sat17__low_total = final.sort_values('s_total_17', ascending=True).head(5)
sat17__low_total
# Out:
#                    state  a_participation_17  a_english_17  a_math_17  \
# 8   District of Columbia                32.0          24.4       23.5
# 7               Delaware                18.0          24.1       23.4
# 12                 Idaho                38.0          21.9       21.8
# 22              Michigan                29.0          24.1       23.7
# 19                 Maine                 8.0          24.2       24.0
#
#     a_reading_17  a_science_17  a_composite_17  s_participation_17  s_rw_17  \
# 8           24.9          23.5            24.2               100.0      482
# 7           24.8          23.6            24.1               100.0      503
# 12          23.0          22.1            22.3                93.0      513
# 22          24.5          23.8            24.1               100.0      509
# 19          24.8          23.7            24.3                95.0      513
#
#     s_math_17  s_total_17  s_participation_18  s_rw_18  s_math_18  s_total_18  \
# ...

# %% [markdown]
# The lowest total scores for the 2017 SAT (from lowest to highest):
#
# 1. District of Columbia
# 2. Delaware
# 3. Idaho
# 4. Michigan
# 5. Maine

# %%
#Lowest total scores for 2018 SAT

sat18__low_total = final.sort_values('s_total_18', ascending=True).head(5)
sat18__low_total
# Out:
#                    state  a_participation_17  a_english_17  a_math_17  \
# 8   District of Columbia                32.0          24.4       23.5
# 7               Delaware                18.0          24.1       23.4
# 48         West Virginia                69.0          20.0       19.4
# 12                 Idaho                38.0          21.9       21.8
# 44                  Utah               100.0          19.5       19.9
#
#     a_reading_17  a_science_17  a_composite_17  s_participation_17  s_rw_17  \
# 8           24.9          23.5            24.2               100.0      482
# 7           24.8          23.6            24.1               100.0      503
# 48          21.2          20.5            20.4                14.0      558
# 12          23.0          22.1            22.3                93.0      513
# 44          20.8          20.6            20.3                 3.0      624
#
#     s_math_17  s_total_17  s_participation_18  s_rw_18  s_math_18  s_total_18  \
# ...

# %% [markdown]
# The lowest total scores for the 2018 SAT (from lowest to highest):
#
# 1. District of Columbia
# 2. Delaware
# 3. West Virginia
# 4. Idaho
# 5. Utah

# %%
#Lowest composite scores for 2017 ACT

act17__low_comp = final.sort_values('a_composite_17', ascending=True).head(5)
act17__low_comp
# Out:
#              state  a_participation_17  a_english_17  a_math_17  a_reading_17  \
# 28          Nevada               100.0          16.3       18.0          18.1
# 24     Mississippi               100.0          18.2       18.1          18.8
# 40  South Carolina               100.0          17.5       18.6          19.1
# 11          Hawaii                90.0          17.8       19.2          19.2
# 33  North Carolina               100.0          17.8       19.3          19.6
#
#     a_science_17  a_composite_17  s_participation_17  s_rw_17  s_math_17  \
# 28          18.2            17.8                26.0      563        553
# 24          18.8            18.6                 2.0      634        607
# 40          18.9            18.7                50.0      543        521
# 11          19.3            19.0                55.0      544        541
# 33          19.3            19.1                49.0      546        535
#
# ...

# %% [markdown]
# The lowest composite scores for the 2017 ACT (from lowest to highest):
#
# 1. Nevada
# 2. Mississippi
# 3. South Carolina
# 4. Hawaii
# 5. North Carolina

# %%
#Lowest composite scores for 2018 SAT

act18__low_comp = final.sort_values('a_composite_18', ascending=True).head(5)
act18__low_comp
# Out:
#              state  a_participation_17  a_english_17  a_math_17  a_reading_17  \
# 28          Nevada               100.0          16.3       18.0          18.1
# 40  South Carolina               100.0          17.5       18.6          19.1
# 24     Mississippi               100.0          18.2       18.1          18.8
# 11          Hawaii                90.0          17.8       19.2          19.2
# 0          Alabama               100.0          18.9       18.4          19.7
#
#     a_science_17  a_composite_17  s_participation_17  s_rw_17  s_math_17  \
# 28          18.2            17.8                26.0      563        553
# 40          18.9            18.7                50.0      543        521
# 24          18.8            18.6                 2.0      634        607
# 11          19.3            19.0                55.0      544        541
# 0           19.4            19.2                 5.0      593        572
#
# ...

# %% [markdown]
# The lowest composite scores for the 2018 ACT (from lowest to highest):
#
# 1. Nevada
# 2. South Carolina
# 3. Mississippi
# 4. Hawaii
# 5. Alabama

# %%
# filter the 'final' dataframe using 's_participation_18' & 's_participation_17' as the columns of interest
# filter out all values not equal to 100.0
Compare = final[(final['s_participation_18'] < 50) & (final['s_participation_17'] < 50) & (final['a_participation_17'] > 50) & (final['a_participation_18'] > 50)]
part_100
# Out:
# Empty DataFrame
# Columns: [state, a_participation_17, a_english_17, a_math_17, a_reading_17, a_science_17, a_composite_17, s_participation_17, s_rw_17, s_math_17, s_total_17, s_participation_18, s_rw_18, s_math_18, s_total_18, a_participation_18, a_composite_18]
# Index: []

# %% [markdown]
# **Do any states with 100% participation on a given test have a rate change year-to-year?**

# %%
# filter the 'final' dataframe using 's_participation_18' & 's_participation_17' as the columns of interest
# filter out all values not equal to 100.0
part_100 = final[(final['s_participation_18'] == 100.0) & (final['s_participation_17'] == 100.0)]
part_100
# Out:
#           state  a_participation_17  a_english_17  a_math_17  a_reading_17  \
# 6   Connecticut                31.0          25.5       24.6          25.6
# 7      Delaware                18.0          24.1       23.4          24.8
# 22     Michigan                29.0          24.1       23.7          24.5
#
#     a_science_17  a_composite_17  s_participation_17  s_rw_17  s_math_17  \
# 6           24.6            25.2               100.0      530        512
# 7           23.6            24.1               100.0      503        492
# 22          23.8            24.1               100.0      509        495
#
#     s_total_17  s_participation_18  s_rw_18  s_math_18  s_total_18  \
# 6         1041               100.0      535        519        1053
# 7          996               100.0      505        492         998
# 22        1005               100.0      511        499        1011
#
#     a_participation_18  a_composite_18
# 6                 26.0            25.6
# ...

# %%
# filter the 'final' dataframe using 'a_participation_18' & 'a_participation_17' as the columns of interest
# filter out all values not equal to 100.0

part_100 = final[(final['a_participation_17'] == 100.0) & (final['a_participation_18'] == 100.0)]
part_100
# Out:
#              state  a_participation_17  a_english_17  a_math_17  a_reading_17  \
# 0          Alabama               100.0          18.9       18.4          19.7
# 3         Arkansas               100.0          18.9       19.0          19.7
# 17        Kentucky               100.0          19.6       19.4          20.5
# 18       Louisiana               100.0          19.4       18.8          19.8
# 24     Mississippi               100.0          18.2       18.1          18.8
# 25        Missouri               100.0          19.8       19.9          20.8
# 26         Montana               100.0          19.0       20.2          21.0
# 28          Nevada               100.0          16.3       18.0          18.1
# 33  North Carolina               100.0          17.8       19.3          19.6
# 36        Oklahoma               100.0          18.5       18.8          20.1
# 40  South Carolina               100.0          17.5       18.6          19.1
# ...

# %%
# filter the 'final' dataframe using the & for all of the participation columns of interest
# filter out all values not equal to 100.0

part_100 = final[(final['s_participation_18'] == 100.0) 
                 & (final['s_participation_17'] == 100.0) 
                 & (final['a_participation_17'] == 100.0) 
                 & (final['a_participation_18'] == 100.0)]
part_100
# Out:
# Empty DataFrame
# Columns: [state, a_participation_17, a_english_17, a_math_17, a_reading_17, a_science_17, a_composite_17, s_participation_17, s_rw_17, s_math_17, s_total_17, s_participation_18, s_rw_18, s_math_18, s_total_18, a_participation_18, a_composite_18]
# Index: []

# %% [markdown]
# It appears that only three states of the states that had 100% participation in both the 2017 SAT and the 2018 SAT (alphabetical order):
#
# 1. Connecticut
# 2. Deleware
# 3. Michigan
#
# It appears that there are severals states that had 100% participation in both the 2017 SAT and the 2018 SAT (alphabetical order):
#
# 1. Alabama
# 2. Arkansas
# 3. Kentucky
# 4. Louisiana
# 5. Mississippi
# 6. Missouri
# 7. Montana
# 8. Nevada
# 9. North Carolina
# 10. Oklahoma
# 11. South Carolina
# 12. Tennessee
# 13. Utah
# 14. Wisconsin
#
# Finally, an evaluation of participation rates across all four tests, there were no states that had 100% participation rate across the board.
#
# Based on this data, it would seem that there is some favorability towards the ACT test over the SAT.

# %% [markdown]
# **Do any states have >50% participation on both tests either year?**

# %%
# filter the 'final' dataframe using 'a_participation_17' & 's_participation_17' as the columns of interest
# filter out all values not less than 50.0

part_below_50 = final[(final['s_participation_17'] < 50.0) 
                 & (final['a_participation_17'] < 50.0)]
part_below_50
# Out:
#      state  a_participation_17  a_english_17  a_math_17  a_reading_17  \
# 37  Oregon                40.0          21.2       21.5          22.4
#
#     a_science_17  a_composite_17  s_participation_17  s_rw_17  s_math_17  \
# 37          21.7            21.8                43.0      560        548
#
#     s_total_17  s_participation_18  s_rw_18  s_math_18  s_total_18  \
# 37        1108                48.0      564        553        1117
#
#     a_participation_18  a_composite_18
# 37                42.0            21.3

# %%
# filter the 'final' dataframe using 'a_participation_18' & 's_participation_18' as the columns of interest
# filter out all values not less than 50.0

part_below_50 = final[(final['s_participation_18'] < 50.0) 
                 & (final['a_participation_18'] < 50.0)]
part_below_50
# Out:
#      state  a_participation_17  a_english_17  a_math_17  a_reading_17  \
# 1   Alaska                65.0          18.7       19.8          20.4
# 37  Oregon                40.0          21.2       21.5          22.4
#
#     a_science_17  a_composite_17  s_participation_17  s_rw_17  s_math_17  \
# 1           19.9            19.8                38.0      547        533
# 37          21.7            21.8                43.0      560        548
#
#     s_total_17  s_participation_18  s_rw_18  s_math_18  s_total_18  \
# 1         1080                43.0      562        544        1106
# 37        1108                48.0      564        553        1117
#
#     a_participation_18  a_composite_18
# 1                 33.0            20.8
# 37                42.0            21.3

# %%
# filter the 'final' dataframe using the & for all of the participation columns of interest
# filter out all values less than 50.0

part_below_50 = final[(final['s_participation_18'] < 50.0) 
                 & (final['s_participation_17'] < 50.0) 
                 & (final['a_participation_17'] < 50.0) 
                 & (final['a_participation_18'] < 50.0)]
part_below_50
# Out:
#      state  a_participation_17  a_english_17  a_math_17  a_reading_17  \
# 37  Oregon                40.0          21.2       21.5          22.4
#
#     a_science_17  a_composite_17  s_participation_17  s_rw_17  s_math_17  \
# 37          21.7            21.8                43.0      560        548
#
#     s_total_17  s_participation_18  s_rw_18  s_math_18  s_total_18  \
# 37        1108                48.0      564        553        1117
#
#     a_participation_18  a_composite_18
# 37                42.0            21.3

# %% [markdown]
# It appears that only one state of the all the states that had less than 50% participation in both the 2017 SAT and the 2017 ACT (alphabetical order):
#
# 1. Oregon
#
# It appears that there are severals states that had less than 50% participation in both the 2018 SAT and the 2018 ACT (alphabetical order):
#
# 1. Alaska
# 2. Oregon
#
# Finally, an evaluation of participation rates across all four tests, there was only one state that had less than 50% participation rate across the board.
#
# 1. Oregon
#
# Based on this data, we can speculate that there is something about Oregon that may be reducing participation rates.

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12, 10))
# Mask to remove upper triangle
mask = np.triu(np.ones_like(final.corr(), dtype=np.bool))
ax = plt.axes()
sns.heatmap(final.corr(), 
            annot=True, 
            cmap="Blues", 
            vmax=1.0, 
            vmin=-1.0,
            ax=ax);
ax.set_title('Heatmap Final', fontsize=30);

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
# def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
#     nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
#     fig, ax = plt.subplots(nrows=nrows, ncols=2) # You'll want to specify your figsize
#     ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
#     for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
#         ax[i].hist(dataframe[column]) # feel free to add more settings
#         # Set titles, labels, etc here for each subplot

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
# Code
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):    
    nrows = int(np.ceil(len(list_of_columns)/2))    
    fig, ax = plt.subplots(nrows=nrows, ncols=2)    
    ax = ax.ravel()   
    for i, column in enumerate(list_of_columns):       
        ax[i].hist(dataframe[column])       
        ax[i].title.set_text(list_of_titles[i])
        ax[i].set_xlabel(list_of_xlabels[i])
        plt.title(column)
        plt.tight_layout()

# %%
subplot_histograms(final, ['a_participation_17',
                           'a_participation_18',
                           's_participation_17',
                           's_participation_18'],
                          ['a_participation_17',
                           'a_participation_18',
                           's_participation_17',
                           's_participation_18'], 
                          ['Percentage',
                           'Percentage',
                           'Percentage',
                           'Percentage'])

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
# scatter plot for SAT vs ACT math scores for 2017
plt.scatter(final['a_math_17'], final['s_math_17'], alpha = 0.8, s = 12);
plt.xlabel('SAT Math Scores 2017', fontsize = 14);
plt.ylabel('ACT Math Scores 2017', fontsize = 14);

# %% [markdown]
# This graph tells us that there is a low negative correlation between the ACT math scores and the SAT math scores in 2017. A negative correlation indicates that when one variable increases, the other decreases and vice versa. In this case, as math scores on the ACT rise, the SAT math scores decrease and vice versa.
#
# Based on previous data, one might speculate that the reason that the data does this is because of the testing structure. Those who do well on the ACT math do well because they are familiar with the ACT format and not the SAT format.

# %%
# scatter plot for SAT vs ACT verbal/reading scores for 2017
plt.scatter(final['a_reading_17'], final['s_rw_17'], alpha = 0.8, s = 12);
plt.xlabel('SAT Reading and Writing Scores 2017', fontsize = 14);
plt.ylabel('ACT Reading Scores 2017', fontsize = 14);

# %% [markdown]
# This graph tells us that there is a low negative correlation between the ACT reading scores and the SAT reading and writing scores. A negative correlation indicates that when one variable increases, the other decreases and vice versa. In this case, as ACT reading scores rise, the SAT reading and writing scores decrease and vice versa.

# %%
# scatter plot for SAT vs ACT total and composite scores for 2017
plt.scatter(final['a_composite_17'], final['s_total_17'], alpha = 0.8, s = 12);
plt.xlabel('SAT Total Scores 2017', fontsize = 14);
plt.ylabel('ACT Composite Scores 2017', fontsize = 14);

# %%
plt.scatter(final['s_participation_17'], final['a_participation_17'], alpha = 0.8, s = 12);
plt.xlabel('SAT Participation 2017', fontsize = 14);
plt.ylabel('ACT Participation 2017', fontsize = 14);

# %%
plt.scatter(final['s_participation_18'], final['a_participation_18'], alpha = 0.8, s = 12);
plt.xlabel('SAT Participation 2018', fontsize = 14);
plt.ylabel('ACT Participation 2018', fontsize = 14);

# %%
# scatter plot for SAT totalscores for 2017 and 2018
plt.scatter(final['s_total_17'], final['s_total_18'], alpha = 0.8, s = 12);
plt.xlabel('SAT Total Scores 2017', fontsize = 14);
plt.ylabel('SAT Total Scores 2018', fontsize = 14);

# %%
# scatter plot for ACT composite scores for 2017 and 2018
plt.scatter(final['a_composite_17'], final['a_composite_18'], alpha = 0.8, s = 12);
plt.xlabel('ACT Composite Scores 2017', fontsize = 14);
plt.ylabel('ACT Composite Scores 2018', fontsize = 14);

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
# ACT Scores for 2017
plt.subplots(figsize = (8,8))
sns.boxplot(data = final[['a_english_17', 'a_math_17', 'a_science_17', 'a_reading_17']], width = 0.5);
plt.title('ACT Sections', fontsize = 24)
plt.ylabel('Score', fontsize = 22)
plt.ylim(15, 28)
# Out:
# (15.0, 28.0)

# %%
# ACT Composite for 2017 and 2018
plt.subplots(figsize = (10,8))
sns.boxplot(data = final[['a_composite_17', 'a_composite_18']], width = 0.5);
plt.title('ACT Composite', fontsize = 24)
plt.ylabel('Score', fontsize = 22)
plt.ylim(15, 28)
# Out:
# (15.0, 28.0)

# %%
# SAT Participation for 2017 and 2018
#cannot include most of ACT data

plt.subplots(figsize = (10,10))
sns.boxplot(data = final[['s_participation_17', 's_participation_18', 'a_participation_17', 'a_participation_18']], width = 0.5);
plt.title('Test Participation', fontsize = 24)
plt.ylabel('Participation Rate', fontsize = 22)
plt.ylim(0, 110)
# Out:
# (0.0, 110.0)

# %%
### SAT Reading and Writing for 2017 and 2018

plt.subplots(figsize = (8,8))
sns.boxplot(data = final[['s_rw_17', 's_rw_18']], width = 0.5);
plt.title('SAT Reading & Writing', fontsize = 24)
plt.ylabel('Score', fontsize = 22)
plt.ylim(425, 700) #200 - #800 for SAT limits #based on minimum maximum
# Out:
# (425.0, 700.0)

# %%
# SAT Math for 2017 and 2018

plt.subplots(figsize = (8,8))
sns.boxplot(data = final[['s_math_17', 's_math_18']], width = 0.5);
plt.title('SAT Math', fontsize = 24)
plt.ylabel('Score', fontsize = 22)
plt.ylim(400, 750)
# Out:
# (400.0, 750.0)

# %%
# SAT Total for 2017 and 2018

plt.subplots(figsize = (8,8))
sns.boxplot(data = final[['s_total_17', 's_total_18']], width = 0.5);
plt.title('SAT Total', fontsize = 24)
plt.ylabel('Score', fontsize = 22)
plt.ylim(850, 1350)
# Out:
# (850.0, 1350.0)

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# Based on my observations, I found three states with interesting results:
# - Colorado
# - Illinois
# - Alaska
#
# The three states I selected are interesting because from 2017 to 2018, they shifted signficantly from using the ACT predominantly to the SAT. For example, Colorado, which had a 100% participation rate on the ACT in 2017, dropped 70% in 2018 and increased 89% on participation for the SAT.
#
# Illinois and Alaska also had significant decreases in ACT participation. However, unlike Illinois and Colorado, Alaska did not see a signficant increase in SAT participation. After seeing these results, I decided to investigate the possible sources of 'why' these changes occurred in each of the three states.
#
# After researching each state, I was unable to find much on Alaska. Considering that they have lower participation rates on both exams, I would imagine that the state has little involvement in standardized testing.
#
# As for Illinois and Colorado, both implemented a switch from ACT to SAT which connects with the increase in the participation rates.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# Based on my research, I chose the state of Illinois.
#
# There were a few key takeaways that led to me to choose, Illinois as the foundation for increasing participation rates amongst graduating seniors. However, although I chose Illinois, their participation rates are actually better than most. The reason I chose them is because my findings suggest that they may provide a great case study to help improve participation rates in other states.
#
# The first finding is that the participation rates in Illinois, for the SAT, were extremely low in 2017. However, despite the low participation rate in that year, in 2018, the rate increased drammatically to 99%. I found an explanation for this flip in my outside research. According to the Chicago Tribune, the ACT has dominated the market share of Illinois standardized testing for nearly two decades. However, in 2016, the state decided to run a bid to determine which standardize test would be provded in the state. That same year, the state awarded the bid to the Collage Board's SAT.
#
# The second finding is that, although the College Board was awarded the bid, participation rates remained low until 2018. What that tells me is that preferences for the ACT remained strong until 2018. Additionally, state funding towards the SAT may have caused an obstacle. For 2 years in a row, the state struggled to form a state budget between 2015 and 2017.
#
# Finally, an analysis of the states with the highest and lowest participation rates revealed that many of the states either required SAT/ACT testing in highschool or provided funding for one test over the other. This state influence has a signficant impact on participation rates.
#
# ### Recommendation
#
# Based on my conclusions, I have the following recommendations:
#
# 1. We should identify the states that play a role in standardized testing. This includes:
#     - states that mandate testing
#     - states that pay for testing; and
#     - states that bid for testing
# 2. Based on the delay between the Illinois decision to support SAT testing and the increase in the SAT participation, we can speculate that testing preference may have an influence on decision making. Therefore, we should develop a brand message that demonstrates why states, schools, parents, and students should choose to take the SAT over the ACT.
# 3. Finally, the third recommendation would be to target the branding message at states that require ACT testing over another.

# %% [markdown]
# ## Bonus: Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# Answers:

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer:

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer:

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer:

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer:

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:
